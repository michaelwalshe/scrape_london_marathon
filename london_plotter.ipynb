# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results = pd.read_csv('./London_Marathon_Big.csv')

# %%
results
# Out:
#        Place (Overall)  Place (Gender)  Place (Category)  \
# 0                  2.0             2.0               2.0
# 1                  3.0             3.0               1.0
# 2                  4.0             4.0               3.0
# 3                  5.0             5.0               4.0
# 4                  6.0             6.0               5.0
# ...                ...             ...               ...
# 89369          41499.0         17059.0            1520.0
# 89370           3370.0           279.0              28.0
# 89371              NaN             NaN               NaN
# 89372          38098.0         14860.0            7825.0
# 89373          42264.0         17592.0            9298.0
#
#                                   Name Sex                            Club  \
# 0                        Gilbert John    M                         Kent AC
# 1                       O'Hanlon Gary    M                   Serpentine RC
# 2                          Payne Tony    M                   Serpentine RC
# 3                       Bayton Steven    M  Hallamshire Harriers Sheffield
# 4                    Greenleaf Andrew    M                   Serpentine RC
# ...                                ...  ..                             ...
# 89369                    Zou Xiaoying    F                             NaN
# 89370               Zubizarreta Maria    F                           Other
# 89371  Zuideveld-Jeremiasse Elisabeth    F                             NaN
# 89372               Zwetsloot Chelsea    F                             NaN
# 89373         Zycinski - Singh Nicole    F                             NaN
#
#        Running Number Category           Finish  Year Country    FirstName  \
# 0                1436    18-39  0 days 02:20:19  2018     GBR        John
# 1                1319    40-44  0 days 02:21:14  2018     IRL        Gary
# 2                1514    18-39  0 days 02:21:53  2018     GBR        Tony
# 3                1815    18-39  0 days 02:22:53  2018     GBR      Steven
# 4                1441    18-39  0 days 02:23:19  2018     GBR      Andrew
# ...               ...      ...              ...   ...     ...          ...
# 89369           50820    50-54  0 days 06:45:37  2019     CHN    Xiaoying
# 89370             779    45-49  0 days 03:10:14  2019     GBR       Maria
# 89371           70687    45-49              NaN  2019     NED   Elisabeth
# 89372            5067    18-39  0 days 05:50:26  2019     GBR     Chelsea
# 89373           21057    18-39  0 days 07:21:56  2019     GBR      Nicole
#
#                    LastName    DSQ  Finish (Total Seconds)
# 0                   Gilbert  False                  8419.0
# 1                  O'Hanlon  False                  8474.0
# 2                     Payne  False                  8513.0
# 3                    Bayton  False                  8573.0
# 4                 Greenleaf  False                  8599.0
# ...                     ...    ...                     ...
# 89369                   Zou  False                 24337.0
# 89370           Zubizarreta  False                 11414.0
# 89371  Zuideveld-Jeremiasse  False                     NaN
# 89372             Zwetsloot  False                 21026.0
# 89373      Zycinski - Singh  False                 26516.0
#
# [89374 rows x 15 columns]

# %%
sns.violinplot(data=results, x='Sex', y='Finish (Total Seconds)')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Finish (Total Seconds)'>

# %%
sns.violinplot(data=results, x='Category', y='Finish (Total Seconds)')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Finish (Total Seconds)'>
